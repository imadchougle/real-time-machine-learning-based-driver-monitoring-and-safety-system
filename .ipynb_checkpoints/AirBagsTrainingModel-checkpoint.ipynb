# %%
import tensorflow as tf

# %%
train_data_directory = r'C:\Users\imadc\Super Folder\NewAirBagData\train'
test_data_directory =  r'C:\Users\imadc\Super Folder\NewAirBagData\test'
validation_data_directory = r'C:\Users\imadc\Super Folder\NewAirBagData\train'

target_size = (110, 110)
batchsize = 4 
cm = 'binary'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale= 1./255,
                                rotation_range=0.2, 
                                shear_range=0.2,
                                zoom_range=0.2, 
                                height_shift_range=0.2,
                                validation_split=0.2)

train_data = train_datagen.flow_from_directory(train_data_directory,
                                              target_size = target_size, 
                                              batch_size = batchsize,
                                              class_mode = cm,
                                              subset = 'training')

validation_data = train_datagen.flow_from_directory(train_data_directory,
                                              target_size = target_size, 
                                              batch_size = batchsize,
                                              class_mode = cm,
                                              subset='validation')

print(f"Training Data: Found {train_data.samples} images belonging to {train_data.num_classes} classes.");
print(f"Validation Data: Found {validation_data.samples} images belonging to {validation_data.num_classes} classes.");
# Out:
# Found 48 images belonging to 2 classes.
# Found 12 images belonging to 2 classes.
# Training Data: Found 48 images belonging to 2 classes.
# Validation Data: Found 12 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale= 1./255)
test_data = test_datagen.flow_from_directory(test_data_directory,
                                              target_size = target_size, 
                                              batch_size = batchsize,
                                              class_mode = cm
                                              )

print(f"Test Data: Found {test_data.samples} images belonging to {test_data.num_classes} classes.")
# Out:
# Found 8 images belonging to 2 classes.
# Test Data: Found 8 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_images(images, labels, class_names):
    plt.figure(figsize=(16, 4))
    for i in range(len(images)):
        plt.subplot(1, 4, i + 1)
        plt.imshow(images[i])
        plt.title(class_names[int(labels[i])])
        plt.axis('off')
    plt.show()

images, labels = next(train_data)
class_names = list(train_data.class_indices.keys())
plot_images(images, labels, class_names)

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout, Input , Flatten , Dense , MaxPooling2D
from tensorflow.keras.optimizers import Adam

#MobileNet pretrained model, just using its learning not its 1000 classes
base_model = MobileNet(include_top=False,
                         weights='imagenet',
                         input_tensor=Input(shape=(110, 110, 3)))

base_output = base_model.output
#base_output.summary()
flattened_output = Flatten()(base_output)

#fully connected layer with 64 neurons
dense_layer = Dense(64, activation='relu')(flattened_output)

#dropout layer to reduce overfitting
dropout_layer = Dropout(0.5)(dense_layer)

#final output layer with 2 neurons beacuse we have 2 classes
output_layer = Dense(1, activation='sigmoid')(dropout_layer)

#custom model specifying the input and output layers
custom_model = Model(inputs=base_model.input, outputs=output_layer)

# Freezeweights of base model 
for layer in base_model.layers:
    layer.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
custom_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 110, 110, 3)]     0
#
#  conv1 (Conv2D)              (None, 55, 55, 32)        864
#
#  conv1_bn (BatchNormalizati  (None, 55, 55, 32)        128
#  on)
#
#  conv1_relu (ReLU)           (None, 55, 55, 32)        0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 55, 55, 32)        288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 55, 55, 32)        128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 55, 55, 32)        0
#
#  conv_pw_1 (Conv2D)          (None, 55, 55, 64)        2048
#
#  conv_pw_1_bn (BatchNormali  (None, 55, 55, 64)        256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 55, 55, 64)        0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 56, 56, 64)        0
#
#  conv_dw_2 (DepthwiseConv2D  (None, 27, 27, 64)        576
#  )
#
#  conv_dw_2_bn (BatchNormali  (None, 27, 27, 64)        256
#  zation)
#
#  conv_dw_2_relu (ReLU)       (None, 27, 27, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 27, 27, 128)       8192
#
#  conv_pw_2_bn (BatchNormali  (None, 27, 27, 128)       512
#  zation)
#
#  conv_pw_2_relu (ReLU)       (None, 27, 27, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D  (None, 27, 27, 128)       1152
#  )
#
#  conv_dw_3_bn (BatchNormali  (None, 27, 27, 128)       512
#  zation)
#
#  conv_dw_3_relu (ReLU)       (None, 27, 27, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 27, 27, 128)       16384
#
#  conv_pw_3_bn (BatchNormali  (None, 27, 27, 128)       512
#  zation)
#
#  conv_pw_3_relu (ReLU)       (None, 27, 27, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 28, 28, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D  (None, 13, 13, 128)       1152
#  )
#
#  conv_dw_4_bn (BatchNormali  (None, 13, 13, 128)       512
#  zation)
#
#  conv_dw_4_relu (ReLU)       (None, 13, 13, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 13, 13, 256)       32768
#
#  conv_pw_4_bn (BatchNormali  (None, 13, 13, 256)       1024
#  zation)
#
#  conv_pw_4_relu (ReLU)       (None, 13, 13, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D  (None, 13, 13, 256)       2304
#  )
#
#  conv_dw_5_bn (BatchNormali  (None, 13, 13, 256)       1024
#  zation)
#
#  conv_dw_5_relu (ReLU)       (None, 13, 13, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 13, 13, 256)       65536
#
#  conv_pw_5_bn (BatchNormali  (None, 13, 13, 256)       1024
#  zation)
#
#  conv_pw_5_relu (ReLU)       (None, 13, 13, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 14, 14, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D  (None, 6, 6, 256)         2304
#  )
#
#  conv_dw_6_bn (BatchNormali  (None, 6, 6, 256)         1024
#  zation)
#
#  conv_dw_6_relu (ReLU)       (None, 6, 6, 256)         0
#
#  conv_pw_6 (Conv2D)          (None, 6, 6, 512)         131072
#
#  conv_pw_6_bn (BatchNormali  (None, 6, 6, 512)         2048
#  zation)
#
#  conv_pw_6_relu (ReLU)       (None, 6, 6, 512)         0
#
#  conv_dw_7 (DepthwiseConv2D  (None, 6, 6, 512)         4608
#  )
#
#  conv_dw_7_bn (BatchNormali  (None, 6, 6, 512)         2048
#  zation)
#
#  conv_dw_7_relu (ReLU)       (None, 6, 6, 512)         0
#
#  conv_pw_7 (Conv2D)          (None, 6, 6, 512)         262144
#
#  conv_pw_7_bn (BatchNormali  (None, 6, 6, 512)         2048
#  zation)
#
#  conv_pw_7_relu (ReLU)       (None, 6, 6, 512)         0
#
#  conv_dw_8 (DepthwiseConv2D  (None, 6, 6, 512)         4608
#  )
#
#  conv_dw_8_bn (BatchNormali  (None, 6, 6, 512)         2048
#  zation)
#
#  conv_dw_8_relu (ReLU)       (None, 6, 6, 512)         0
#
#  conv_pw_8 (Conv2D)          (None, 6, 6, 512)         262144
#
#  conv_pw_8_bn (BatchNormali  (None, 6, 6, 512)         2048
#  zation)
#
#  conv_pw_8_relu (ReLU)       (None, 6, 6, 512)         0
#
#  conv_dw_9 (DepthwiseConv2D  (None, 6, 6, 512)         4608
#  )
#
#  conv_dw_9_bn (BatchNormali  (None, 6, 6, 512)         2048
#  zation)
#
#  conv_dw_9_relu (ReLU)       (None, 6, 6, 512)         0
#
#  conv_pw_9 (Conv2D)          (None, 6, 6, 512)         262144
#
#  conv_pw_9_bn (BatchNormali  (None, 6, 6, 512)         2048
#  zation)
#
#  conv_pw_9_relu (ReLU)       (None, 6, 6, 512)         0
#
#  conv_dw_10 (DepthwiseConv2  (None, 6, 6, 512)         4608
#  D)
#
#  conv_dw_10_bn (BatchNormal  (None, 6, 6, 512)         2048
#  ization)
#
#  conv_dw_10_relu (ReLU)      (None, 6, 6, 512)         0
#
#  conv_pw_10 (Conv2D)         (None, 6, 6, 512)         262144
#
#  conv_pw_10_bn (BatchNormal  (None, 6, 6, 512)         2048
#  ization)
#
#  conv_pw_10_relu (ReLU)      (None, 6, 6, 512)         0
#
#  conv_dw_11 (DepthwiseConv2  (None, 6, 6, 512)         4608
#  D)
#
#  conv_dw_11_bn (BatchNormal  (None, 6, 6, 512)         2048
#  ization)
#
#  conv_dw_11_relu (ReLU)      (None, 6, 6, 512)         0
#
#  conv_pw_11 (Conv2D)         (None, 6, 6, 512)         262144
#
#  conv_pw_11_bn (BatchNormal  (None, 6, 6, 512)         2048
#  ization)
#
#  conv_pw_11_relu (ReLU)      (None, 6, 6, 512)         0
#
#  conv_pad_12 (ZeroPadding2D  (None, 7, 7, 512)         0
#  )
#
#  conv_dw_12 (DepthwiseConv2  (None, 3, 3, 512)         4608
#  D)
#
#  conv_dw_12_bn (BatchNormal  (None, 3, 3, 512)         2048
#  ization)
#
#  conv_dw_12_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 3, 3, 1024)        524288
#
#  conv_pw_12_bn (BatchNormal  (None, 3, 3, 1024)        4096
#  ization)
#
#  conv_pw_12_relu (ReLU)      (None, 3, 3, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2  (None, 3, 3, 1024)        9216
#  D)
#
#  conv_dw_13_bn (BatchNormal  (None, 3, 3, 1024)        4096
#  ization)
#
#  conv_dw_13_relu (ReLU)      (None, 3, 3, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 3, 3, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormal  (None, 3, 3, 1024)        4096
#  ization)
#
#  conv_pw_13_relu (ReLU)      (None, 3, 3, 1024)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 64)                589888
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 3818817 (14.57 MB)
# Trainable params: 589953 (2.25 MB)
# Non-trainable params: 3228864 (12.32 MB)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
#Callbacks and conditions for stopping the epochs and specific runs and storing the best values in the model

val_accuracy_monitor = ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, patience=5, verbose = 3) 

accuracy_monitor = ModelCheckpoint('best_model.h5', monitor='accuracy', save_best_only=True , patience = 5 ,verbose=3)

val_loss_monitor = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True , patience = 5 , verbose=3)

earlystopping_condition = EarlyStopping(monitor= 'val_loss' , patience=5 , restore_best_weights=True , verbose = 3)

learning_rate = ReduceLROnPlateau(monitor= 'val_loss', patience = 5 , verboes = 3)


training_monitors = [val_accuracy_monitor, accuracy_monitor , val_loss_monitor, earlystopping_condition, learning_rate]

# %%
train_steps_per_epoch = len(train_data)
val_steps_per_epoch = len(validation_data)

print("Number of training steps per epoch:", train_steps_per_epoch)
print("Number of validation steps per epoch:", val_steps_per_epoch)
# Out:
# Number of training steps per epoch: 12
# Number of validation steps per epoch: 3

# %%
custom_model.compile(optimizer='Adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
hist = custom_model.fit(train_data,
                           steps_per_epoch=train_steps_per_epoch,
                           epochs=15,
                           validation_data=validation_data,
                           validation_steps=val_steps_per_epoch,
                           callbacks=training_monitors)
# Out:
# Epoch 1/15
# 11/12 [==========================>...] - ETA: 0s - loss: 1.9538 - accuracy: 0.7500
# Epoch 1: val_accuracy improved from -inf to 0.91667, saving model to best_model.h5
#
# Epoch 1: accuracy improved from -inf to 0.77083, saving model to best_model.h5
# C:\Users\imadc\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1: val_loss improved from inf to 0.22304, saving model to best_model.h5
# 12/12 [==============================] - 5s 164ms/step - loss: 1.7910 - accuracy: 0.7708 - val_loss: 0.2230 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 2/15
# 11/12 [==========================>...] - ETA: 0s - loss: 0.1866 - accuracy: 0.9773
# Epoch 2: val_accuracy improved from 0.91667 to 1.00000, saving model to best_model.h5
#
# Epoch 2: accuracy improved from 0.77083 to 0.97917, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.22304 to 0.00000, saving model to best_model.h5
# 12/12 [==============================] - 1s 108ms/step - loss: 0.1711 - accuracy: 0.9792 - val_loss: 4.6726e-11 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/15
# 11/12 [==========================>...] - ETA: 0s - loss: 2.4757e-06 - accuracy: 1.0000
# Epoch 3: val_accuracy did not improve from 1.00000
#
# Epoch 3: accuracy improved from 0.97917 to 1.00000, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.00000
# 12/12 [==============================] - 1s 64ms/step - loss: 2.2694e-06 - accuracy: 1.0000 - val_loss: 3.8221e-10 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 4: val_accuracy did not improve from 1.00000
#
# Epoch 4: accuracy did not improve from 1.00000
#
# Epoch 4: val_loss improved from 0.00000 to 0.00000, saving model to best_model.h5
# 12/12 [==============================] - 1s 108ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 4.6639e-13 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 3.1430e-04 - accuracy: 1.0000
# Epoch 5: val_accuracy did not improve from 1.00000
#
# Epoch 5: accuracy did not improve from 1.00000
#
# Epoch 5: val_loss improved from 0.00000 to 0.00000, saving model to best_model.h5
# 12/12 [==============================] - 1s 75ms/step - loss: 3.1430e-04 - accuracy: 1.0000 - val_loss: 4.0732e-15 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/15
# 11/12 [==========================>...] - ETA: 0s - loss: 3.3335e-05 - accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 1.00000
#
# Epoch 6: accuracy did not improve from 1.00000
#
# Epoch 6: val_loss did not improve from 0.00000
# 12/12 [==============================] - 1s 43ms/step - loss: 3.2492e-05 - accuracy: 1.0000 - val_loss: 9.5342e-06 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/15
# 11/12 [==========================>...] - ETA: 0s - loss: 1.2011e-05 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 1.00000
#
# Epoch 7: accuracy did not improve from 1.00000
#
# Epoch 7: val_loss did not improve from 0.00000
# 12/12 [==============================] - 1s 43ms/step - loss: 1.1010e-05 - accuracy: 1.0000 - val_loss: 2.3498e-11 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 8/15
# 11/12 [==========================>...] - ETA: 0s - loss: 1.2623e-06 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 1.00000
#
# Epoch 8: accuracy did not improve from 1.00000
#
# Epoch 8: val_loss did not improve from 0.00000
# 12/12 [==============================] - 1s 43ms/step - loss: 1.1571e-06 - accuracy: 1.0000 - val_loss: 1.3943e-13 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 9/15
# 11/12 [==========================>...] - ETA: 0s - loss: 6.5594e-09 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 1.00000
#
# Epoch 9: accuracy did not improve from 1.00000
#
# Epoch 9: val_loss did not improve from 0.00000
# 12/12 [==============================] - 1s 47ms/step - loss: 6.0127e-09 - accuracy: 1.0000 - val_loss: 3.2982e-12 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 10/15
# 11/12 [==========================>...] - ETA: 0s - loss: 2.9467e-06 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 1.00000
#
# Epoch 10: accuracy did not improve from 1.00000
#
# Epoch 10: val_loss improved from 0.00000 to 0.00000, saving model to best_model.h5
# 12/12 [==============================] - 1s 65ms/step - loss: 2.7012e-06 - accuracy: 1.0000 - val_loss: 3.5875e-15 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 11/15
# 11/12 [==========================>...] - ETA: 0s - loss: 5.2925e-07 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 1.00000
#
# Epoch 11: accuracy did not improve from 1.00000
#
# Epoch 11: val_loss did not improve from 0.00000
# 12/12 [==============================] - 1s 50ms/step - loss: 4.8514e-07 - accuracy: 1.0000 - val_loss: 8.3529e-09 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 8.1897e-10 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 1.00000
#
# Epoch 12: accuracy did not improve from 1.00000
#
# Epoch 12: val_loss improved from 0.00000 to 0.00000, saving model to best_model.h5
# 12/12 [==============================] - 1s 80ms/step - loss: 8.1897e-10 - accuracy: 1.0000 - val_loss: 3.1648e-15 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2019 - accuracy: 0.9792
# Epoch 13: val_accuracy did not improve from 1.00000
#
# Epoch 13: accuracy did not improve from 1.00000
#
# Epoch 13: val_loss did not improve from 0.00000
# 12/12 [==============================] - 1s 48ms/step - loss: 0.2019 - accuracy: 0.9792 - val_loss: 2.7725e-13 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 14/15
# 11/12 [==========================>...] - ETA: 0s - loss: 9.4593e-06 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 1.00000
#
# Epoch 14: accuracy did not improve from 1.00000
#
# Epoch 14: val_loss did not improve from 0.00000
# 12/12 [==============================] - 1s 48ms/step - loss: 8.6710e-06 - accuracy: 1.0000 - val_loss: 3.6399e-13 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 5.7975e-09 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 1.00000
#
# Epoch 15: accuracy did not improve from 1.00000
#
# Epoch 15: val_loss did not improve from 0.00000
# 12/12 [==============================] - 1s 53ms/step - loss: 5.7975e-09 - accuracy: 1.0000 - val_loss: 3.1975e-14 - val_accuracy: 1.0000 - lr: 1.0000e-05

# %%
model_path = r'C:\Users\imadc\Super Folder\modelss\MobileNetAirBagModel.h5'
custom_model.save(model_path)

print(f"Model saved to {model_path}")
# Out:
# Model saved to C:\Users\imadc\Super Folder\modelss\MobileNetAirBagModel.h5

# %%
training_loss = hist.history['loss']
training_accuracy = hist.history['accuracy']

# %%
import matplotlib.pyplot as plt

num_epochs_completed = len(training_loss)
min_val_loss_epoch = training_loss.index(min(training_loss)) + 1 

plt.figure(figsize=(5, 3))
plt.plot(range(1, num_epochs_completed + 1), training_loss, label='Training Loss', marker='o')
plt.axvline(x=min_val_loss_epoch, color='r', linestyle='--', label='Min Loss Epoch')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('AirBagMobileNet Training  Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
max_val_accuracy_epoch = training_accuracy.index(max(training_accuracy)) + 1  

plt.figure(figsize=(5, 3))
plt.plot(range(1, num_epochs_completed + 1), training_accuracy, label='Accuracy', marker='o')
plt.axvline(x=max_val_accuracy_epoch, color='r', linestyle='--', label='Epochs')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('AirBagMobileNet Training Accuracy')
plt.legend()
plt.grid(True)
plt.show()
